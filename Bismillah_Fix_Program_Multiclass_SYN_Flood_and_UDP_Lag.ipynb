# %%
   from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
df = pd.read_csv("drive/MyDrive/Dataset/DataProcess/SYNandUDPLagDataProcessing.csv")
df.info()
x=df.iloc[:,df.columns != 'Label']
y=df.iloc[:,-1]
print("x\n",x.info())
y = pd.DataFrame(y)
print('y\n',y.info())
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (89) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383388 entries, 0 to 383387
# Data columns (total 92 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Unnamed: 0                    383388 non-null  int64
#  1   Unnamed: 0.1                  383388 non-null  int64
#  2   Unnamed: 0.1.1                383388 non-null  int64
#  3   Unnamed: 0.1.1.1              383388 non-null  int64
#  4   Unnamed: 0.1.1.1.1            383388 non-null  int64
#  5   Flow ID                       383388 non-null  object
#  6    Source IP                    383388 non-null  object
#  7    Source Port                  383388 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# count  383388.000000  383388.000000   383388.000000     383388.000000
# mean    95846.500000   95846.500000    95846.500000      95846.500000
# std     55337.363419   55337.363419    55337.363419      55337.363419
# min         0.000000       0.000000        0.000000          0.000000
# 25%     47923.000000   47923.000000    47923.000000      47923.000000
# 50%     95846.500000   95846.500000    95846.500000      95846.500000
# 75%    143770.000000  143770.000000   143770.000000     143770.000000
# max    191693.000000  191693.000000   191693.000000     191693.000000
#
#        Unnamed: 0.1.1.1.1    Source Port   Destination Port       Protocol  \
# count       383388.000000  383388.000000      383388.000000  383388.000000
# mean        242450.169484   36787.044660       32771.201389       6.001857
# std         138443.169738   18669.632699       18924.616971       0.148396
# ...

# %%
normalized_df=(df-df.mean())/df.std()
normalized_df=normalized_df.drop(' Flow Packets/s',axis=1)
normalized_df=normalized_df.drop('Flow Bytes/s',axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(100,200))
cor = normalized_df.corr()
sn.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
normalized_df.head()

# %%
normalized_df=normalized_df.drop('Unnamed: 0', axis=1)
normalized_df=normalized_df.drop('Unnamed: 0.1.1', axis=1)

# %%
y=pd.DataFrame(y)

# %%
normalized_df.describe()

# %%
normalized_x=normalized_df.iloc[:,normalized_df.columns != 'Label']

# %%
normalized_x.describe()

# %%
from sklearn.model_selection import train_test_split
import numpy as np
X_train, X_test, y_train, y_test = train_test_split(normalized_x, y, test_size=0.25, random_state=00, )
y_train = np.array(y_train)
y_test =np.array(y_test)
print("TRAIN:", X_train.index)
print("TEST:", X_test.index)

# %%
normalized_x.info()

# %%
y.info()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(X_train, y_train):
    print("TRAIN:", train_index)
for train_index, test_index in kf.split(X_test, y_test):
    print("TEST:", test_index)

# %%
pipeline = make_pipeline(StandardScaler(), RandomForestClassifier(n_estimators=100, max_depth=10))

scorex = cross_val_score(pipeline, X=X_train, y=y_train, cv=10, n_jobs=1)
print('Cross Validation accuracy scores: %s' % scorex)

print('Cross Validation accuracy: %.3f +/- %.3f' % (np.mean(scorex),np.std(scorex)))

# %%
X_train = X_train.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
X_test = X_test.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

# %%
def get_stacking():
	level0 = list()
	level0.append(('lr', LogisticRegression()))
	level0.append(('cart', DecisionTreeClassifier()))
	level1 = LogisticRegression()
	model = StackingClassifier(estimators=level0, final_estimator=level1, cv=10)
	return model

# %%
models = [RandomForestClassifier(),AdaBoostClassifier(),get_stacking()]
classifiers = ["RandomForest","AdaBoost","Stacking" ]
scores = []

# %% [markdown]
# Data Train 75%

# %%
for model in models:
    model.fit(X_train,y_train)
    y_pred = model.predict(X_train)
    score = accuracy_score(y_train, y_pred)*100
    scores.append(score)
    print("Accuracy of the model is: ", score)
    conf_matrix = confusion_matrix(y_train,y_pred)
    report = classification_report(y_train,y_pred)
    print("Confusion Matrix:\n",conf_matrix)
    print("Report:\n",report)
    print("\n==============***===============")

# %% [markdown]
# Data Train with k fold

# %%
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(X_train, y_train):
    print("TRAIN:", train_index)
# Out:
# TRAIN: [ 28755  28756  28757 ... 287538 287539 287540]
# TRAIN: [     0      1      2 ... 287538 287539 287540]
# TRAIN: [     0      1      2 ... 287538 287539 287540]
# TRAIN: [     0      1      2 ... 287538 287539 287540]
# TRAIN: [     0      1      2 ... 287538 287539 287540]
# TRAIN: [     0      1      2 ... 287538 287539 287540]
# TRAIN: [     0      1      2 ... 287538 287539 287540]
# TRAIN: [     0      1      2 ... 287538 287539 287540]
# TRAIN: [     0      1      2 ... 287538 287539 287540]
# TRAIN: [     0      1      2 ... 258784 258785 258786]

# %% [markdown]
# Accuracy Data train with k fold and algorithm

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle

kf = StratifiedKFold(n_splits=10 , shuffle=True)

score = cross_val_score(RandomForestClassifier(), X_train, y_train, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {score}')
print(f'Average score: {"{:.2f}".format(score.mean())}')

filenameRFA1 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning1.pkl'
filenameRFA2 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning2.pkl'
filenameRFA3 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning3.pkl'
filenameRFA4 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning4.pkl'
filenameRFA5 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning5.pkl'
filenameRFA6 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning6.pkl'
filenameRFA7 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning7.pkl'
filenameRFA8 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning8.pkl'
filenameRFA9 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning9.pkl'
filenameRFA10 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracybeforetuning10.pkl'

pickle.dump(score, open(filenameRFA1, f'wb'))
pickle.dump(score, open(filenameRFA2, f'wb'))
pickle.dump(score, open(filenameRFA3, f'wb'))
pickle.dump(score, open(filenameRFA4, f'wb'))
pickle.dump(score, open(filenameRFA5, f'wb'))
pickle.dump(score, open(filenameRFA6, f'wb'))
pickle.dump(score, open(filenameRFA7, f'wb'))
pickle.dump(score, open(filenameRFA8, f'wb'))
pickle.dump(score, open(filenameRFA9, f'wb'))
pickle.dump(score, open(filenameRFA10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle

kf = StratifiedKFold(n_splits=10 , shuffle=True)

score = cross_val_score(AdaBoostClassifier(), X_train, y_train, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {score}')
print(f'Average score: {"{:.2f}".format(score.mean())}')

filenameABA1 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning1.pkl'
filenameABA2 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning2.pkl'
filenameABA3 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning3.pkl'
filenameABA4 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning4.pkl'
filenameABA5 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning5.pkl'
filenameABA6 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning6.pkl'
filenameABA7 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning7.pkl'
filenameABA8 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning8.pkl'
filenameABA9 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning9.pkl'
filenameABA10 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracybeforetuning10.pkl'

pickle.dump(score, open(filenameABA1, f'wb'))
pickle.dump(score, open(filenameABA2, f'wb'))
pickle.dump(score, open(filenameABA3, f'wb'))
pickle.dump(score, open(filenameABA4, f'wb'))
pickle.dump(score, open(filenameABA5, f'wb'))
pickle.dump(score, open(filenameABA6, f'wb'))
pickle.dump(score, open(filenameABA7, f'wb'))
pickle.dump(score, open(filenameABA8, f'wb'))
pickle.dump(score, open(filenameABA9, f'wb'))
pickle.dump(score, open(filenameABA10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

score = cross_val_score(get_stacking(), X_train, y_train, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {score}')
print(f'Average score: {"{:.2f}".format(score.mean())}')

filenamexA1 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning1.pkl'
filenamexA2 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning2.pkl'
filenamexA3 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning3.pkl'
filenamexA4 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning4.pkl'
filenamexA5 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning5.pkl'
filenamexA6 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning6.pkl'
filenamexA7 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning7.pkl'
filenamexA8 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning8.pkl'
filenamexA9 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning9.pkl'
filenamexA10 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracybeforetuning10.pkl'

pickle.dump(score, open(filenamexA1, f'wb'))
pickle.dump(score, open(filenamexA2, f'wb'))
pickle.dump(score, open(filenamexA3, f'wb'))
pickle.dump(score, open(filenamexA4, f'wb'))
pickle.dump(score, open(filenamexA5, f'wb'))
pickle.dump(score, open(filenamexA6, f'wb'))
pickle.dump(score, open(filenamexA7, f'wb'))
pickle.dump(score, open(filenamexA8, f'wb'))
pickle.dump(score, open(filenamexA9, f'wb'))
pickle.dump(score, open(filenamexA10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# Recall Data train with k fold and algorithm

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle



kf = StratifiedKFold(n_splits=10 , shuffle=True)

score = cross_val_score(RandomForestClassifier(), X_train, y_train, cv=kf, scoring="recall_macro")
print(f'Scores for each fold are: {score}')

filenameRFR1 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallbeforetuning1.pkl'
filenameRFR2 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallbeforetuning2.pkl'
filenameRFR3 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallbeforetuning3.pkl'
filenameRFR4 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallbeforetuning4.pkl'
filenameRFR5 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallbeforetuning5.pkl'
filenameRFR6 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallbeforetuning6.pkl'
filenameRFR7 = 'drive/MyDrive/Dataset/DataProcess/RFfolrecallbeforetuning7.pkl'
filenameRFR8 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallbeforetuning8.pkl'
filenameRFR9 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallbeforetuning9.pkl'
filenameRFR10 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallbeforetuning10.pkl'

pickle.dump(score, open(filenameRFR1, f'wb'))
pickle.dump(score, open(filenameRFR2, f'wb'))
pickle.dump(score, open(filenameRFR3, f'wb'))
pickle.dump(score, open(filenameRFR4, f'wb'))
pickle.dump(score, open(filenameRFR5, f'wb'))
pickle.dump(score, open(filenameRFR6, f'wb'))
pickle.dump(score, open(filenameRFR7, f'wb'))
pickle.dump(score, open(filenameRFR8, f'wb'))
pickle.dump(score, open(filenameRFR9, f'wb'))
pickle.dump(score, open(filenameRFR10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

score = cross_val_score(AdaBoostClassifier(), X_train, y_train, cv= kf,  scoring="recall_macro")
print(f'Scores for each fold are: {score}')


filenameABR1 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallbeforetuning1.pkl'
filenameABR2 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallbeforetuning2.pkl'
filenameABR3 = 'drive/MyDrive/Dataset/DataProcess/ABfolrecallbeforetuning3.pkl'
filenameABR4 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallbeforetuning4.pkl'
filenameABR5 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallbeforetuning5.pkl'
filenameABR6 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallbeforetuning6.pkl'
filenameABR7 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallbeforetuning7.pkl'
filenameABR8 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallbeforetuning8.pkl'
filenameABR9 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallbeforetuning9.pkl'
filenameABR10 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallbeforetuning10.pkl'

pickle.dump(score, open(filenameABR1, f'wb'))
pickle.dump(score, open(filenameABR2, f'wb'))
pickle.dump(score, open(filenameABR3, f'wb'))
pickle.dump(score, open(filenameABR4, f'wb'))
pickle.dump(score, open(filenameABR5, f'wb'))
pickle.dump(score, open(filenameABR6, f'wb'))
pickle.dump(score, open(filenameABR7, f'wb'))
pickle.dump(score, open(filenameABR8, f'wb'))
pickle.dump(score, open(filenameABR9, f'wb'))
pickle.dump(score, open(filenameABR10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

score = cross_val_score(get_stacking(), X_train, y_train, cv= kf, scoring="recall_macro")
print(f'Scores for each fold are: {score}')



filenamexR1 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuningg1.pkl'
filenamexR2 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuningg2.pkl'
filenamexR3 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuningg3.pkl'
filenamexR4 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuning4.pkl'
filenamexR5 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuning5.pkl'
filenamexR6 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuning6.pkl'
filenamexR7 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuning7.pkl'
filenamexR8 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuning8.pkl'
filenamexR9 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuning9.pkl'
filenamexR10 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallbeforetuning10.pkl'

pickle.dump(score, open(filenamexR1, f'wb'))
pickle.dump(score, open(filenamexR2, f'wb'))
pickle.dump(score, open(filenamexR3, f'wb'))
pickle.dump(score, open(filenamexR4, f'wb'))
pickle.dump(score, open(filenamexR5, f'wb'))
pickle.dump(score, open(filenamexR6, f'wb'))
pickle.dump(score, open(filenamexR7, f'wb'))
pickle.dump(score, open(filenamexR8, f'wb'))
pickle.dump(score, open(filenamexR9, f'wb'))
pickle.dump(score, open(filenamexR10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# Precision Data Train with k fold and algorithm

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

score = cross_val_score(RandomForestClassifier(), X_train, y_train, cv= kf, scoring="precision_macro")
print(f'Scores for each fold are: {score}')


filenameRFP1 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning1.pkl'
filenameRFP2 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning2.pkl'
filenameRFP3 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning3.pkl'
filenameRFP4 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning4.pkl'
filenameRFP5 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning5.pkl'
filenameRFP6 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning6.pkl'
filenameRFP7 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning7.pkl'
filenameRFP8 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning8.pkl'
filenameRFP9 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning9.pkl'
filenameRFP10 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionbeforetuning10.pkl'

pickle.dump(score, open(filenameRFP1, f'wb'))
pickle.dump(score, open(filenameRFP2, f'wb'))
pickle.dump(score, open(filenameRFP3, f'wb'))
pickle.dump(score, open(filenameRFP4, f'wb'))
pickle.dump(score, open(filenameRFP5, f'wb'))
pickle.dump(score, open(filenameRFP6, f'wb'))
pickle.dump(score, open(filenameRFP7, f'wb'))
pickle.dump(score, open(filenameRFP8, f'wb'))
pickle.dump(score, open(filenameRFP9, f'wb'))
pickle.dump(score, open(filenameRFP10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

score = cross_val_score(AdaBoostClassifier(), X_train, y_train, cv= kf, scoring="precision_macro")
print(f'Scores for each fold are: {score}')



filenameABP1 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning1.pkl'
filenameABP2 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning2.pkl'
filenameABP3 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning3.pkl'
filenameABP4 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning4.pkl'
filenameABP5 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning5.pkl'
filenameABP6 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning6.pkl'
filenameABP7 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning7.pkl'
filenameABP8 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning8.pkl'
filenameABP9 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning9.pkl'
filenameABP10 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionbeforetuning10.pkl'

pickle.dump(score, open(filenameABP1, f'wb'))
pickle.dump(score, open(filenameABP2, f'wb'))
pickle.dump(score, open(filenameABP3, f'wb'))
pickle.dump(score, open(filenameABP4, f'wb'))
pickle.dump(score, open(filenameABP5, f'wb'))
pickle.dump(score, open(filenameABP6, f'wb'))
pickle.dump(score, open(filenameABP7, f'wb'))
pickle.dump(score, open(filenameABP8, f'wb'))
pickle.dump(score, open(filenameABP9, f'wb'))
pickle.dump(score, open(filenameABP10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

score = cross_val_score(get_stacking(), X_train, y_train, cv= kf, scoring="precision_macro")
print(f'Scores for each fold are: {score}')



filenamexP1 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning1.pkl'
filenamexP2 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning2.pkl'
filenamexP3 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning3.pkl'
filenamexP4 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning4.pkl'
filenamexP5 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning5.pkl'
filenamexP6 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning6.pkl'
filenamexP7 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning7.pkl'
filenamexP8 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning8.pkl'
filenamexP9 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning9.pkl'
filenamexP10 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionbeforetuning10.pkl'

pickle.dump(score, open(filenamexP1, f'wb'))
pickle.dump(score, open(filenamexP2, f'wb'))
pickle.dump(score, open(filenamexP3, f'wb'))
pickle.dump(score, open(filenamexP4, f'wb'))
pickle.dump(score, open(filenamexP5, f'wb'))
pickle.dump(score, open(filenamexP6, f'wb'))
pickle.dump(score, open(filenamexP7, f'wb'))
pickle.dump(score, open(filenamexP8, f'wb'))
pickle.dump(score, open(filenamexP9, f'wb'))
pickle.dump(score, open(filenamexP10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# Accuracy Data train with k fold and algorithm with tuning

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

scoress = cross_val_score(RandomForestClassifier(n_estimators=100), X_train, y_train, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {score}')
print(f'Average score: {"{:.2f}".format(score.mean())}')

filenamesRFA1 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning1.pkl'
filenamesRFA2 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning2.pkl'
filenamesRFA3 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning3.pkl'
filenamesRFA4 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning4.pkl'
filenamesRFA5 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning5.pkl'
filenamesRFA6 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning6.pkl'
filenamesRFA7 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning7.pkl'
filenamesRFA8 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning8.pkl'
filenamesRFA9 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning9.pkl'
filenamesRFA10 = 'drive/MyDrive/Dataset/DataProcess/RFfoldaccuracywithtuning10.pkl'

pickle.dump(scoress, open(filenamesRFA1, f'wb'))
pickle.dump(scoress, open(filenamesRFA2, f'wb'))
pickle.dump(scoress, open(filenamesRFA3, f'wb'))
pickle.dump(scoress, open(filenamesRFA4, f'wb'))
pickle.dump(scoress, open(filenamesRFA5, f'wb'))
pickle.dump(scoress, open(filenamesRFA6, f'wb'))
pickle.dump(scoress, open(filenamesRFA7, f'wb'))
pickle.dump(scoress, open(filenamesRFA8, f'wb'))
pickle.dump(scoress, open(filenamesRFA9, f'wb'))
pickle.dump(scoress, open(filenamesRFA10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

scoress = cross_val_score(AdaBoostClassifier(n_estimators=100), X_train, y_train, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {scoress}')
print(f'Average score: {"{:.2f}".format(scoress.mean())}')

filenamesABA1 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning1.pkl'
filenamesABA2 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning2.pkl'
filenamesABA3 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning3.pkl'
filenamesABA4 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning4.pkl'
filenamesABA5 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning5.pkl'
filenamesABA6 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning6.pkl'
filenamesABA7 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning7.pkl'
filenamesABA8 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning8.pkl'
filenamesABA9 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning9.pkl'
filenamesABA10 = 'drive/MyDrive/Dataset/DataProcess/ABfoldaccuracywithtuning10.pkl'

pickle.dump(scoress, open(filenamesABA1, f'wb'))
pickle.dump(scoress, open(filenamesABA2, f'wb'))
pickle.dump(scoress, open(filenamesABA3, f'wb'))
pickle.dump(scoress, open(filenamesABA4, f'wb'))
pickle.dump(scoress, open(filenamesABA5, f'wb'))
pickle.dump(scoress, open(filenamesABA6, f'wb'))
pickle.dump(scoress, open(filenamesABA7, f'wb'))
pickle.dump(scoress, open(filenamesABA8, f'wb'))
pickle.dump(scoress, open(filenamesABA9, f'wb'))
pickle.dump(scoress, open(filenamesABA10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

scoress = cross_val_score(get_stacking(), X_train, y_train, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {scoress}')
print(f'Average score: {"{:.2f}".format(scoress.mean())}')


filenamesxA1 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuning1.pkl'
filenamesxA2 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuning2.pkl'
filenamesxA3 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuning3.pkl'
filenamesxA4 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuning4.pkl'
filenamesxA5 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuningg5.pkl'
filenamesxA6 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuningg6.pkl'
filenamesxA7 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuning7.pkl'
filenamesxA8 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuningg8.pkl'
filenamesxA9 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuning9.pkl'
filenamesxA10 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldaccuracywithtuning10.pkl'

pickle.dump(scoress, open(filenamesxA1, f'wb'))
pickle.dump(scoress, open(filenamesxA2, f'wb'))
pickle.dump(scoress, open(filenamesxA3, f'wb'))
pickle.dump(scoress, open(filenamesxA4, f'wb'))
pickle.dump(scoress, open(filenamesxA5, f'wb'))
pickle.dump(scoress, open(filenamesxA6, f'wb'))
pickle.dump(scoress, open(filenamesxA7, f'wb'))
pickle.dump(scoress, open(filenamesxA8, f'wb'))
pickle.dump(scoress, open(filenamesxA9, f'wb'))
pickle.dump(scoress, open(filenamesxA10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# Recall Data train with k fold and algorithm with tuning

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
from sklearn.metrics import confusion_matrix
import pickle



kf = StratifiedKFold(n_splits=10 , shuffle=True)

scoress = cross_val_score(RandomForestClassifier(n_estimators=100), X_train, y_train, cv=kf, scoring="recall_macro")
print(f'Scores for each fold are: {scoress }')


filenamesRFR1 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallwithtuning1.pkl'
filenamesRFR2 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallwithtuning2.pkl'
filenamesRFR3 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallwithtuning3.pkl'
filenamesRFR4 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallwithtuning4.pkl'
filenamesRFR5 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallwithtuning5.pkl'
filenamesRFR6 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallwithtuning6.pkl'
filenamesRFR7 = 'drive/MyDrive/Dataset/DataProcess/RFfolrecallwithtuning7.pkl'
filenamesRFR8 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallwithtuning8.pkl'
filenamesRFR9 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallwithtuning9.pkl'
filenamesRFR10 = 'drive/MyDrive/Dataset/DataProcess/RFfoldrecallwithtuning10.pkl'

pickle.dump(scoress, open(filenamesRFR1, f'wb'))
pickle.dump(scoress, open(filenamesRFR2, f'wb'))
pickle.dump(scoress, open(filenamesRFR3, f'wb'))
pickle.dump(scoress, open(filenamesRFR4, f'wb'))
pickle.dump(scoress, open(filenamesRFR5, f'wb'))
pickle.dump(scoress, open(filenamesRFR6, f'wb'))
pickle.dump(scoress, open(filenamesRFR7, f'wb'))
pickle.dump(scoress, open(filenamesRFR8, f'wb'))
pickle.dump(scoress, open(filenamesRFR9, f'wb'))
pickle.dump(scoress, open(filenamesRFR10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

scoress = cross_val_score(AdaBoostClassifier(n_estimators=100), X_train, y_train, cv= kf,  scoring="recall_macro")
print(f'Scores for each fold are: {scoress}')

filenamesABR1 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallwithtuning1.pkl'
filenamesABR2 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallwithtuning2.pkl'
filenamesABR3 = 'drive/MyDrive/Dataset/DataProcess/ABfolrecallwithtuning3.pkl'
filenamesABR4 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallwithtuning4.pkl'
filenamesABR5 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallwithtuning5.pkl'
filenamesABR6 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallwithtuning6.pkl'
filenamesABR7 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallwithtuning7.pkl'
filenamesABR8 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallwithtuning8.pkl'
filenamesABR9 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecallwithtuning9.pkl'
filenamesABR10 = 'drive/MyDrive/Dataset/DataProcess/ABfoldrecalwithtuning10.pkl'

pickle.dump(scoress, open(filenamesABR1, f'wb'))
pickle.dump(scoress, open(filenamesABR2, f'wb'))
pickle.dump(scoress, open(filenamesABR3, f'wb'))
pickle.dump(scoress, open(filenamesABR4, f'wb'))
pickle.dump(scoress, open(filenamesABR5, f'wb'))
pickle.dump(scoress, open(filenamesABR6, f'wb'))
pickle.dump(scoress, open(filenamesABR7, f'wb'))
pickle.dump(scoress, open(filenamesABR8, f'wb'))
pickle.dump(scoress, open(filenamesABR9, f'wb'))
pickle.dump(scoress, open(filenamesABR10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

scoress = cross_val_score(get_stacking(), X_train, y_train, cv= kf, scoring="recall_macro")
print(f'Scores for each fold are: {scoress}')


filenamesxR1 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuningg1.pkl'
filenamesxR2 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuningg2.pkl'
filenamesxR3 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuningg3.pkl'
filenamesxR4 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuning4.pkl'
filenamesxR5 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuning5.pkl'
filenamesxR6 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuning6.pkl'
filenamesxR7 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuning7.pkl'
filenamesxR8 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuning8.pkl'
filenamesxR9 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuning9.pkl'
filenamesxR10 = 'drive/MyDrive/Dataset/DataProcess/Stackingrecallwithtuning10.pkl'

pickle.dump(scoress, open(filenamesxR1, f'wb'))
pickle.dump(scoress, open(filenamesxR2, f'wb'))
pickle.dump(scoress, open(filenamesxR3, f'wb'))
pickle.dump(scoress, open(filenamesxR4, f'wb'))
pickle.dump(scoress, open(filenamesxR5, f'wb'))
pickle.dump(scoress, open(filenamesxR6, f'wb'))
pickle.dump(scoress, open(filenamesxR7, f'wb'))
pickle.dump(scoress, open(filenamesxR8, f'wb'))
pickle.dump(scoress, open(filenamesxR9, f'wb'))
pickle.dump(scoress, open(filenamesxR10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# Precision Data Train with k fold and algorithm with tuning

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

scoress = cross_val_score(RandomForestClassifier(n_estimators=100), X_train, y_train, cv= kf, scoring="precision_macro")
print(f'Scores for each fold are: {scoress}')


filenamesRFP1 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning1.pkl'
filenamesRFP2 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning2.pkl'
filenamesRFP3 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning3.pkl'
filenamesRFP4 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning4.pkl'
filenamesRFP5 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning5.pkl'
filenamesRFP6 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning6.pkl'
filenamesRFP7 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning7.pkl'
filenamesRFP8 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning8.pkl'
filenamesRFP9 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning9.pkl'
filenamesRFP10 = 'drive/MyDrive/Dataset/DataProcess/RFfoldprecisionwithtuning10.pkl'

pickle.dump(scoress, open(filenamesRFP1, f'wb'))
pickle.dump(scoress, open(filenamesRFP2, f'wb'))
pickle.dump(scoress, open(filenamesRFP3, f'wb'))
pickle.dump(scoress, open(filenamesRFP4, f'wb'))
pickle.dump(scoress, open(filenamesRFP5, f'wb'))
pickle.dump(scoress, open(filenamesRFP6, f'wb'))
pickle.dump(scoress, open(filenamesRFP7, f'wb'))
pickle.dump(scoress, open(filenamesRFP8, f'wb'))
pickle.dump(scoress, open(filenamesRFP9, f'wb'))
pickle.dump(scoress, open(filenamesRFP10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

scoress = cross_val_score(AdaBoostClassifier(n_estimators=100), X_train, y_train, cv= kf, scoring="precision_macro")
print(f'Scores for each fold are: {scoress}')



filenamesABP1 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning1.pkl'
filenamesABP2 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning2.pkl'
filenamesABP3 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning3.pkl'
filenamesABP4 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning4.pkl'
filenamesABP5 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning5.pkl'
filenamesABP6 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning6.pkl'
filenamesABP7 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning7.pkl'
filenamesABP8 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning8.pkl'
filenamesABP9 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning9.pkl'
filenamesABP10 = 'drive/MyDrive/Dataset/DataProcess/ABfoldprecisionwithtuning10.pkl'

pickle.dump(scoress, open(filenamesABP1, f'wb'))
pickle.dump(scoress, open(filenamesABP2, f'wb'))
pickle.dump(scoress, open(filenamesABP3, f'wb'))
pickle.dump(scoress, open(filenamesABP4, f'wb'))
pickle.dump(scoress, open(filenamesABP5, f'wb'))
pickle.dump(scoress, open(filenamesABP6, f'wb'))
pickle.dump(scoress, open(filenamesABP7, f'wb'))
pickle.dump(scoress, open(filenamesABP8, f'wb'))
pickle.dump(scoress, open(filenamesABP9, f'wb'))
pickle.dump(scoress, open(filenamesABP10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
import pickle


kf = StratifiedKFold(n_splits=10 , shuffle=True)

scoress = cross_val_score(get_stacking(), X_train, y_train, cv= kf, scoring="precision_macro")
print(f'Scores for each fold are: {scoress}')


filenamesxP1 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning1.pkl'
filenamesxP2 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning2.pkl'
filenamesxP3 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning3.pkl'
filenamesxP4 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning4.pkl'
filenamesxP5 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning5.pkl'
filenamesxP6 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning6.pkl'
filenamesxP7 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning7.pkl'
filenamesxP8 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning8.pkl'
filenamesxP9 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning9.pkl'
filenamesxP10 = 'drive/MyDrive/Dataset/DataProcess/Stackingfoldprecisionwithtuning10.pkl'

pickle.dump(scoress, open(filenamesxP1, f'wb'))
pickle.dump(scoress, open(filenamesxP2, f'wb'))
pickle.dump(scoress, open(filenamesxP3, f'wb'))
pickle.dump(scoress, open(filenamesxP4, f'wb'))
pickle.dump(scoress, open(filenamesxP5, f'wb'))
pickle.dump(scoress, open(filenamesxP6, f'wb'))
pickle.dump(scoress, open(filenamesxP7, f'wb'))
pickle.dump(scoress, open(filenamesxP8, f'wb'))
pickle.dump(scoress, open(filenamesxP9, f'wb'))
pickle.dump(scoress, open(filenamesxP10, f'wb'))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
def get_stackingcv1():
	level0 = list()
	level0.append(('lr', LogisticRegression()))
	level0.append(('cart', DecisionTreeClassifier()))
	level1 = LogisticRegression()
	modelxxxs = StackingClassifier(estimators=level0, final_estimator=level1, cv=2)
	return modelxxxs

# %%
modelxxxxs= [RandomForestClassifier(),AdaBoostClassifier(),get_stackingcv1()]
classifiers = ["RandomForest","AdaBoost","Stacking" ]
scoresx = []

# %%
modelxxxs = pickle.load(open(filenamexA10, 'rb'))
modelxxxs = pickle.load(open(filenamexR10, 'rb'))
modelxxxs = pickle.load(open(filenamexP10, 'rb'))
modelxxxxs = pickle.load(open(filenameRFA1, 'rb'))
modelxxxxs = pickle.load(open(filenameRFR1, 'rb'))
modelxxxxs = pickle.load(open(filenameRFP1, 'rb'))
modelxxxxs = pickle.load(open(filenameABA2, 'rb'))
modelxxxxs = pickle.load(open(filenameABR2, 'rb'))
modelxxxxs = pickle.load(open(filenameABP2, 'rb'))

# %%
def get_stackingcv2():
	level0 = list()
	level0.append(('lr', LogisticRegression()))
	level0.append(('cart', DecisionTreeClassifier()))
	level1 = LogisticRegression()
	modelxxxss = StackingClassifier(estimators=level0, final_estimator=level1, cv=2)
	return modelxxxss

# %%
modelxxxxss= [RandomForestClassifier(n_estimators=100),AdaBoostClassifier(n_estimators=100),get_stackingcv2()]
classifiers = ["RandomForest","AdaBoost","Stacking" ]
scoresxx = []

# %%
modelxxxss = pickle.load(open(filenamesxA3, 'rb'))
modelxxxss = pickle.load(open(filenamesxR3, 'rb'))
modelxxxss = pickle.load(open(filenamesxP3, 'rb'))
modelxxxxss = pickle.load(open(filenamesRFA4, 'rb'))
modelxxxxss = pickle.load(open(filenamesRFR4, 'rb'))
modelxxxxss = pickle.load(open(filenamesABA10, 'rb'))
modelxxxxss = pickle.load(open(filenamesABR10, 'rb'))
modelxxxxss = pickle.load(open(filenamesABP10, 'rb'))

# %% [markdown]
# Tuning Data Train 75%

# %%
def get_stackingcv():
	level0 = list()
	level0.append(('lr', LogisticRegression()))
	level0.append(('cart', DecisionTreeClassifier()))
	level1 = LogisticRegression()
	modelss = StackingClassifier(estimators=level0, final_estimator=level1, cv=2)
	return modelss

# %%
modelsss = [RandomForestClassifier(n_estimators=100),AdaBoostClassifier(n_estimators=100),get_stackingcv()]
classifiers = ["RandomForest","AdaBoost","Stacking" ]
scoress = []

# %%
for modelss in modelsss:
    modelss.fit(X_train,y_train)
    y_pred = modelss.predict(X_test)
    score = accuracy_score(y_test, y_pred)*100
    scores.append(score)
    print("Accuracy of the model is: ", score)
    conf_matrix = confusion_matrix(y_test,y_pred)
    report = classification_report(y_test,y_pred)
    print("Confusion Matrix:\n",conf_matrix)
    print("Report:\n",report)
    print("\n==============***===============")

# %% [markdown]
# Best K fold with Data Test before tuning

# %%
for modelxxxs in modelxxxxs:
    modelxxxs.fit(X_test,y_test)
    y_pred = modelxxxs.predict(X_test)
    score = accuracy_score(y_test, y_pred)*100
    scores.append(score)
    print("Accuracy of the model is: ", score)
    report = classification_report(y_test,y_pred)
    print("Report:\n",report)
    print("\n==============***===============")

# %% [markdown]
# Best K fold with Data Test with tuning

# %%
for modelxxxss in modelxxxxss:
    modelxxxss.fit(X_test,y_test)
    y_pred = modelxxxss.predict(X_test)
    score = accuracy_score(y_test, y_pred)*100
    scores.append(score)
    print("Accuracy of the model is: ", score)
    report = classification_report(y_test,y_pred)
    print("Report:\n",report)
    print("\n==============***===============")
